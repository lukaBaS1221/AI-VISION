# %% [markdown]
# <a href="https://colab.research.google.com/github/lukaBaS1221/AI-VISION/blob/main/ai-vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import requests
from io import BytesIO
import re
import os

# %%
import json
from google.colab import userdata

key_json_str = userdata.get('GOOGLE_APPLICATION_CREDENTIALS_JSON')
key_json = json.loads(key_json_str)

with open("key.json", "w") as f:
    json.dump(key_json, f)


os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "key.json"

# %%
from transformers import  AutoTokenizer
import torch
from PIL import Image

# %%
from datasets import load_dataset

# %%
dataset = load_dataset("detection-datasets/coco", split="train[:100]")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/58.0 [00:00<?, ?B/s]
# Resolving data files:   0%|          | 0/40 [00:00<?, ?it/s]
# dataset_infos.json:   0%|          | 0.00/2.10k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0/40 [00:00<?, ?files/s]
# data/train-00000-of-00040-67e35002d15215(…): reconstructing file:   0%|          |  0.00B /  485MB
# data/train-00000-of-00040-67e35002d15215(…): downloading bytes:           |  0.00B
# data/train-00001-of-00040-2c2b33b9504aa8(…): reconstructing file:   0%|          |  0.00B /  489MB
# data/train-00001-of-00040-2c2b33b9504aa8(…): downloading bytes:           |  0.00B
# data/train-00002-of-00040-58e30306870b1d(…): reconstructing file:   0%|          |  0.00B /  474MB
# data/train-00002-of-00040-58e30306870b1d(…): downloading bytes:           |  0.00B
# data/train-00003-of-00040-a77e00648e4239(…): reconstructing file:   0%|          |  0.00B /  480MB
# data/train-00003-of-00040-a77e00648e4239(…): downloading bytes:           |  0.00B
# data/train-00004-of-00040-1df1755d6f7c9b(…): reconstructing file:   0%|          |  0.00B /  480MB
# data/train-00004-of-00040-1df1755d6f7c9b(…): downloading bytes:           |  0.00B
# data/train-00005-of-00040-29ccfc8f52cfc9(…): reconstructing file:   0%|          |  0.00B /  473MB
# data/train-00005-of-00040-29ccfc8f52cfc9(…): downloading bytes:           |  0.00B
# data/train-00006-of-00040-76f2d663d51dca(…): reconstructing file:   0%|          |  0.00B /  483MB
# data/train-00006-of-00040-76f2d663d51dca(…): downloading bytes:           |  0.00B
# data/train-00007-of-00040-797508421c59b9(…): reconstructing file:   0%|          |  0.00B /  477MB
# data/train-00007-of-00040-797508421c59b9(…): downloading bytes:           |  0.00B
# data/train-00008-of-00040-7ad10a6d6b442e(…): reconstructing file:   0%|          |  0.00B /  481MB
# data/train-00008-of-00040-7ad10a6d6b442e(…): downloading bytes:           |  0.00B
# data/train-00009-of-00040-edc6018bb7abee(…): reconstructing file:   0%|          |  0.00B /  475MB
# data/train-00009-of-00040-edc6018bb7abee(…): downloading bytes:           |  0.00B
# data/train-00010-of-00040-068d922af9742c(…): reconstructing file:   0%|          |  0.00B /  480MB
# data/train-00010-of-00040-068d922af9742c(…): downloading bytes:           |  0.00B
# data/train-00011-of-00040-2cf010e9592da4(…): reconstructing file:   0%|          |  0.00B /  483MB
# data/train-00011-of-00040-2cf010e9592da4(…): downloading bytes:           |  0.00B
# data/train-00012-of-00040-e26d7a054b1f8c(…): reconstructing file:   0%|          |  0.00B /  477MB
# data/train-00012-of-00040-e26d7a054b1f8c(…): downloading bytes:           |  0.00B
# data/train-00013-of-00040-00a967ab3e2568(…): reconstructing file:   0%|          |  0.00B /  476MB
# data/train-00013-of-00040-00a967ab3e2568(…): downloading bytes:           |  0.00B
# data/train-00014-of-00040-4f6a348405f372(…): reconstructing file:   0%|          |  0.00B /  477MB
# data/train-00014-of-00040-4f6a348405f372(…): downloading bytes:           |  0.00B
# data/train-00015-of-00040-ae8972f628750c(…): reconstructing file:   0%|          |  0.00B /  479MB
# data/train-00015-of-00040-ae8972f628750c(…): downloading bytes:           |  0.00B
# data/train-00016-of-00040-37711297359438(…): reconstructing file:   0%|          |  0.00B /  478MB
# data/train-00016-of-00040-37711297359438(…): downloading bytes:           |  0.00B
# data/train-00017-of-00040-e2f542f29ca613(…): reconstructing file:   0%|          |  0.00B /  477MB
# data/train-00017-of-00040-e2f542f29ca613(…): downloading bytes:           |  0.00B
# data/train-00018-of-00040-3650ae2c12a832(…): reconstructing file:   0%|          |  0.00B /  474MB
# data/train-00018-of-00040-3650ae2c12a832(…): downloading bytes:           |  0.00B
# data/train-00019-of-00040-f262669c6302eb(…): reconstructing file:   0%|          |  0.00B /  476MB
# data/train-00019-of-00040-f262669c6302eb(…): downloading bytes:           |  0.00B
# data/train-00020-of-00040-d2763ce5e7ab09(…): reconstructing file:   0%|          |  0.00B /  486MB
# data/train-00020-of-00040-d2763ce5e7ab09(…): downloading bytes:           |  0.00B
# data/train-00021-of-00040-fb98d35ab4e6ca(…): reconstructing file:   0%|          |  0.00B /  482MB
# data/train-00021-of-00040-fb98d35ab4e6ca(…): downloading bytes:           |  0.00B
# data/train-00022-of-00040-c4f90a7435af52(…): reconstructing file:   0%|          |  0.00B /  487MB
# data/train-00022-of-00040-c4f90a7435af52(…): downloading bytes:           |  0.00B
# data/train-00023-of-00040-31db5fa16e24d3(…): reconstructing file:   0%|          |  0.00B /  477MB
# data/train-00023-of-00040-31db5fa16e24d3(…): downloading bytes:           |  0.00B
# data/train-00024-of-00040-786ee9123ad04e(…): reconstructing file:   0%|          |  0.00B /  476MB
# data/train-00024-of-00040-786ee9123ad04e(…): downloading bytes:           |  0.00B
# data/train-00025-of-00040-369c096f8c7d7a(…): reconstructing file:   0%|          |  0.00B /  479MB
# data/train-00025-of-00040-369c096f8c7d7a(…): downloading bytes:           |  0.00B
# data/train-00026-of-00040-709cf1a409a269(…): reconstructing file:   0%|          |  0.00B /  470MB
# data/train-00026-of-00040-709cf1a409a269(…): downloading bytes:           |  0.00B
# data/train-00027-of-00040-c99041dbf75151(…): reconstructing file:   0%|          |  0.00B /  482MB
# data/train-00027-of-00040-c99041dbf75151(…): downloading bytes:           |  0.00B
# data/train-00028-of-00040-5e11f3d596cb0d(…): reconstructing file:   0%|          |  0.00B /  480MB
# data/train-00028-of-00040-5e11f3d596cb0d(…): downloading bytes:           |  0.00B
# data/train-00029-of-00040-988997614786b5(…): reconstructing file:   0%|          |  0.00B /  481MB
# data/train-00029-of-00040-988997614786b5(…): downloading bytes:           |  0.00B
# data/train-00030-of-00040-497df2d4082da4(…): reconstructing file:   0%|          |  0.00B /  481MB
# data/train-00030-of-00040-497df2d4082da4(…): downloading bytes:           |  0.00B
# data/train-00031-of-00040-541a6ccf9f2109(…): reconstructing file:   0%|          |  0.00B /  476MB
# data/train-00031-of-00040-541a6ccf9f2109(…): downloading bytes:           |  0.00B
# data/train-00032-of-00040-659aee4f72e8f5(…): reconstructing file:   0%|          |  0.00B /  479MB
# data/train-00032-of-00040-659aee4f72e8f5(…): downloading bytes:           |  0.00B
# data/train-00033-of-00040-0074f368f67338(…): reconstructing file:   0%|          |  0.00B /  478MB
# data/train-00033-of-00040-0074f368f67338(…): downloading bytes:           |  0.00B
# data/train-00034-of-00040-edcd109018ecaf(…): reconstructing file:   0%|          |  0.00B /  481MB
# data/train-00034-of-00040-edcd109018ecaf(…): downloading bytes:           |  0.00B
# data/train-00035-of-00040-c8fd4fb1bb9311(…): reconstructing file:   0%|          |  0.00B /  478MB
# data/train-00035-of-00040-c8fd4fb1bb9311(…): downloading bytes:           |  0.00B
# data/train-00036-of-00040-5d6d294fbed2af(…): reconstructing file:   0%|          |  0.00B /  478MB
# data/train-00036-of-00040-5d6d294fbed2af(…): downloading bytes:           |  0.00B
# data/train-00037-of-00040-cb1276b8824445(…): reconstructing file:   0%|          |  0.00B /  479MB
# data/train-00037-of-00040-cb1276b8824445(…): downloading bytes:           |  0.00B
# data/train-00038-of-00040-15a5fd14791741(…): reconstructing file:   0%|          |  0.00B /  482MB
# data/train-00038-of-00040-15a5fd14791741(…): downloading bytes:           |  0.00B
# data/train-00039-of-00040-f1a97fa690638b(…): reconstructing file:   0%|          |  0.00B /  474MB
# data/train-00039-of-00040-f1a97fa690638b(…): downloading bytes:           |  0.00B
# data/val-00000-of-00002-c4f2e391ee4aba11(…): reconstructing file:   0%|          |  0.00B /  404MB
# data/val-00000-of-00002-c4f2e391ee4aba11(…): downloading bytes:           |  0.00B
# data/val-00001-of-00002-7af5414a3b178949(…): reconstructing file:   0%|          |  0.00B /  404MB
# data/val-00001-of-00002-7af5414a3b178949(…): downloading bytes:           |  0.00B
# Generating train split:   0%|          | 0/117266 [00:00<?, ? examples/s]
# Generating val split:   0%|          | 0/4952 [00:00<?, ? examples/s]

# %%
import google.generativeai as genai
gemini_model = genai.GenerativeModel('gemini-flash-latest')
# Out:
# /usr/local/lib/python3.13/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %%
PEOPLE = ['man', 'men', 'woman', 'women', 'person', 'people', 'boy', 'boys', 'girl', 'girls', 'child', 'children']
OUTDOOR = ["forest", "park", "street", "bench", "road", "highway", "alley", "sidewalk", "city", "town", "village", "neighborhood", "downtown", "urban area", "suburban area", "rural area", "countryside", "field", "meadow", "grassland", "farmland", "farm", "orchard", "vineyard", "mountain", "hill", "valley", "cliff", "plateau", "canyon", "desert", "dune", "oasis", "beach", "shore", "coast", "seaside", "bay", "harbor", "port", "island", "lake", "river", "stream", "waterfall", "pond", "wetland", "marsh", "swamp", "jungle", "rainforest", "savanna", "trail", "path", "hiking trail", "campground", "campsite", "picnic area", "playground", "garden", "botanical garden", "zoo", "stadium", "sports field", "soccer field", "basketball court", "tennis court", "skate park", "plaza", "square", "market", "outdoor market", "festival area", "construction site", "parking lot", "gas station", "bridge", "tunnel entrance", "railway", "train station exterior", "bus stop", "airport exterior", "runway", "industrial area", "factory exterior", "warehouse exterior", "dock", "pier", "boardwalk", "resort", "outdoor cafe", "restaurant terrace", "courtyard", "campus", "schoolyard", "playfield"]

INDOOR = ["living room", "bedroom", "kitchen", "bathroom", "dining room", "hallway", "corridor", "staircase", "basement", "attic", "garage", "laundry room", "home office", "study room", "closet", "pantry", "apartment", "house interior", "hotel room", "hotel lobby", "office", "conference room", "meeting room", "classroom", "lecture hall", "library", "computer lab", "cafeteria", "restaurant interior", "cafe interior", "bar interior", "shopping mall", "store", "supermarket", "hospital room", "clinic", "waiting room", "gym", "movie theater", "museum", "art gallery", "airport terminal", "train station interior", "elevator", "warehouse interior", "factory interior", "server room"]

ANIMALS = ["dog", "dogs", "cat", "cats", "bird", "birds", "horse", "horses", "cow", "cows", "sheep", "goat", "goats", "pig", "pigs", "rabbit", "rabbits", "deer", "fox", "foxes", "wolf", "wolves", "bear", "bears", "lion", "lions", "tiger", "tigers", "elephant", "elephants", "monkey", "monkeys", "fish", "dolphin", "dolphins", "shark", "sharks", "whale", "whales", "snake", "snakes", "lizard", "lizards", "turtle", "turtles", "frog", "frogs"]

ACTIONS = ["walking", "running", "standing", "sitting", "lying down", "jumping", "climbing", "talking", "eating", "drinking", "working", "studying", "reading", "writing", "typing", "using phone", "playing", "exercising", "driving", "riding", "cooking", "cleaning", "shopping", "waiting"]

PEOPLE_PATTERN = re.compile(r'(\d+)\s*(man|men|woman|women|person|people|boy|boys|girl|girls|child|children)')
ANIMAL_PATTERN = re.compile(r'(\d+)\s*(dog|dogs|cat|cats|bird|birds|horse|horses|cow|cows|sheep|goat|goats|pig|pigs|rabbit|rabbits|deer|fox|foxes|wolf|wolves|bear|bears|lion|lions|tiger|tigers|elephant|elephants|monkey|monkeys|fish|dolphin|dolphins|shark|sharks|whale|whales|snake|snakes|lizard|lizards|turtle|turtles|frog|frogs)')

def analyze_image(image):

    prompt = (
        "Describe this image concisely in 2 to 3 sentences with a maximum of 30 words . "
        "Use numeric counts (e.g., 3, not three,)(if there is one subject dont mention the value, otherwise use numeric counts). "
        "Use general people terms. "
        "Format exactly as: "
        "Description: ... People: X. Animals: Y. Scene: indoor/outdoor. Activity: ..."
    )

    response = gemini_model.generate_content([image, prompt])
    text = response.text.lower()

    basic = ""
    people_count = 0
    animal_count = 0
    scene = "unknown"
    activity = "unknown"

    desc_match = re.search(r'description:\s*(.*?)(?:people:|animals:|scene:|activity:|$)', text, re.DOTALL)
    if desc_match:
        basic = desc_match.group(1).strip()
    else:
        basic = text.strip()

    people_match = re.search(r'people:\s*(\d+)', text)
    if people_match:
        people_count = int(people_match.group(1))
    else:
        matches = PEOPLE_PATTERN.findall(basic)
        people_count = sum(int(m[0]) for m in matches) if matches else 0

    animal_match = re.search(r'animals:\s*(\d+)', text)
    if animal_match:
        animal_count = int(animal_match.group(1))
    else:
        matches = ANIMAL_PATTERN.findall(basic)
        animal_count = sum(int(m[0]) for m in matches) if matches else 0

    scene_match = re.search(r'scene:\s*(indoor|outdoor)', text)
    if scene_match:
        scene = scene_match.group(1)
    else:
        outdoor_hits = sum(w in basic for w in OUTDOOR)
        indoor_hits = sum(w in basic for w in INDOOR)
        if outdoor_hits > indoor_hits:
            scene = "outdoor"
        elif indoor_hits > outdoor_hits:
            scene = "indoor"

    activity_match = re.search(r'activity:\s*(.*)', text)
    if activity_match:
        activity = activity_match.group(1).strip()
    else:
        activity = next((a for a in ACTIONS if a in basic), "static")

    enhanced = (
        f"This is an {scene} scene. "
        f"It features {people_count} person(s) and {animal_count} animal(s). "
        f"Main activity: {activity}. "
        f"Description: {basic.capitalize()}."
    )

    return {
        "basic": basic,
        "enhanced": enhanced,
        "people": people_count,
        "animals": animal_count,
        "scene": scene,
        "activity": activity
    }

# %%
test_idx = 73
result = analyze_image(dataset[test_idx]['image'])


plt.imshow(dataset[test_idx]['image'])
plt.axis('off')
plt.title(f"Image {test_idx} - Analysis")
plt.show()

print(f"Basic Description: {result['basic']}")
print(f"\nEnhanced Description: {result['enhanced']}")
print(f"\nAnalysis: {result['people']} people, {result['animals']} animals, {result['scene']} scene, activity: {result['activity']}")
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      54         try:
# ---> 55             return callable_(*args, **kwargs)
#      56         except grpc.RpcError as exc:
#
# /usr/local/lib/python3.13/dist-packages/grpc/_interceptor.py in __call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     275     ) -> Any:
# --> 276         response, ignored_call = self._with_call(
#     277             request,
#
# /usr/local/lib/python3.13/dist-packages/grpc/_interceptor.py in _with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     330         )
# --> 331         return call.result(), call
#     332
#
# /usr/local/lib/python3.13/dist-packages/grpc/_channel.py in result(self, timeout)
#     446         """See grpc.Future.result."""
# --> 447         raise self
#     448
#
# /usr/local/lib/python3.13/dist-packages/grpc/_interceptor.py in continuation(new_details, request)
#     313             try:
# --> 314                 response, call = self._thunk(new_method).with_call(
#     315                     request,
#
# /usr/local/lib/python3.13/dist-packages/grpc/_channel.py in with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1181         )
# -> 1182         return _end_unary_response_blocking(state, call, True, None)
#    1183
#
# /usr/local/lib/python3.13/dist-packages/grpc/_channel.py in _end_unary_response_blocking(state, call, with_call, deadline)
#     998         return state.response
# --> 999     raise _InactiveRpcError(state)  # pytype: disable=not-instantiable
#    1000
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.PERMISSION_DENIED
# 	details = "Access to Gemini API is restricted with service accounts. Use authorization keys instead. https://docs.cloud.google.com/docs/authentication/api-keys#api-keys-bound-sa"
# 	debug_error_string = "PERMISSION_DENIED:Access to Gemini API is restricted with service accounts. Use authorization keys instead. https://docs.cloud.google.com/docs/authentication/api-keys#api-keys-bound-sa"
# >
#
# The above exception was the direct cause of the following exception:
#
# PermissionDenied                          Traceback (most recent call last)
# /tmp/ipykernel_2060/3406379011.py in <cell line: 0>()
#       1 test_idx = 73
# ----> 2 result = analyze_image(dataset[test_idx]['image'])
#       3
#       4
#       5 plt.imshow(dataset[test_idx]['image'])
#
# /tmp/ipykernel_2060/3449385455.py in analyze_image(image)
#      21     )
#      22
# ---> 23     response = gemini_model.generate_content([image, prompt])
#      24     text = response.text.lower()
#      25
#
# /usr/local/lib/python3.13/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#     333                     **request_options,
#
# /usr/local/lib/python3.13/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     833
#     834         # Send the request.
# --> 835         response = rpc(
#     836             request,
#     837             retry=retry,
#
# /usr/local/lib/python3.13/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, compression, *args, **kwargs)
#     126             kwargs["compression"] = compression
#     127
# --> 128         return wrapped_func(*args, **kwargs)
#     129
#     130
#
# /usr/local/lib/python3.13/dist-packages/google/api_core/retry/retry_unary.py in retry_wrapped_func(*args, **kwargs)
#     292                 self._initial, self._maximum, multiplier=self._multiplier
#     293             )
# --> 294             return retry_target(
#     295                 target,
#     296                 self._predicate,
#
# /usr/local/lib/python3.13/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154         except Exception as exc:
#     155             # defer to shared logic for handling errors
# --> 156             next_sleep = _retry_error_helper(
#     157                 exc,
#     158                 deadline,
#
# /usr/local/lib/python3.13/dist-packages/google/api_core/retry/retry_base.py in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     214             original_timeout,
#     215         )
# --> 216         raise final_exc from source_exc
#     217     if on_error_fn is not None:
#     218         on_error_fn(exc)
#
# /usr/local/lib/python3.13/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145     while True:
#     146         try:
# --> 147             result = target()
#     148             if inspect.isawaitable(result):
#     149                 warnings.warn(_ASYNC_RETRY_WARNING)
#
# /usr/local/lib/python3.13/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     128                 kwargs["timeout"] = remaining_timeout
#     129
# --> 130             return func(*args, **kwargs)
#     131
#     132         return func_with_timeout
#
# /usr/local/lib/python3.13/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      55             return callable_(*args, **kwargs)
#      56         except grpc.RpcError as exc:
# ---> 57             raise exceptions.from_grpc_error(exc) from exc
#      58
#      59     return error_remapped_callable
#
# PermissionDenied: 403 Access to Gemini API is restricted with service accounts. Use authorization keys instead. https://docs.cloud.google.com/docs/authentication/api-keys#api-keys-bound-sa

# %%
pip install deep-translator

# %%
from deep_translator import GoogleTranslator

def translate_to_georgian(text):

    translator = GoogleTranslator(source='en', target='ka')
    return translator.translate(text)


result = analyze_image(dataset[test_idx]['image'])

georgian_enhanced = translate_to_georgian(result['enhanced'])

print(f"English Enhanced: {result['enhanced']}")
print(f"\nქართული თარგმანი: {georgian_enhanced}")

# %%
# !pip install -q google-cloud-texttospeech

# %%
import io
import gradio as gr
from google.cloud import texttospeech



def english_tts(text):
    """
    Generate English audio using Google Cloud TTS.
    Returns path to saved .wav file.
    """
    client = texttospeech.TextToSpeechClient()
    input_text = texttospeech.SynthesisInput(text=text)
    voice = texttospeech.VoiceSelectionParams(
        language_code="en-US",
        name="en-US-Standard-A"
    )
    audio_config = texttospeech.AudioConfig(
        audio_encoding=texttospeech.AudioEncoding.LINEAR16
    )
    response = client.synthesize_speech(
        input=input_text,
        voice=voice,
        audio_config=audio_config
    )

    audio_file = "english_audio.wav"
    with open(audio_file, "wb") as f:
        f.write(response.audio_content)
    return audio_file


def gradio_pipeline(image):

    result = analyze_image(image)
    english_text = result["enhanced"]

    georgian_text = translate_to_georgian(english_text)

    audio_file = english_tts(english_text)

    return english_text, georgian_text, audio_file


with gr.Blocks(title="Image → English Audio") as demo:
    gr.Markdown("## 🖼️ Image → English → Georgian → 🔊 Audio")



    image_input = gr.Image(type="pil", label="Upload Image")

    english_out = gr.Textbox(label="English Description", lines=4)
    georgian_out = gr.Textbox(label="ქართული აღწერა", lines=4)
    audio_out = gr.Audio(label="English Audio", type="filepath")

    run_btn = gr.Button("Analyze Image")
    run_btn.click(
        fn=gradio_pipeline,
        inputs=image_input,
        outputs=[english_out, georgian_out, audio_out]

    )

    gr.Image("TBC.png", label="Logo", interactive=False)

demo.launch(debug=True)
